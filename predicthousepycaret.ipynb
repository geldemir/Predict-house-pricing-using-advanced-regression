# %%
#!pip install pycaret

# %%
import pandas as pd

# %%
df1=pd.read_csv("test.csv")
df2=pd.read_csv("train.csv")

# %%
df=df1.append(df2)

# %%
pip install numba==0.53
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from pycaret.regression import *

# %%
exp_model=setup(data=df,target='SalePrice')
# Out:
#                                Description             Value
# 0                               session_id              3018
# 1                                   Target         SalePrice
# 2                            Original Data        (2919, 81)
# 3                           Missing Values              True
# 4                         Numeric Features                24
# 5                     Categorical Features                56
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set       (1025, 359)
# 10                    Transformed Test Set        (435, 359)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# ...

# %%
best_model=compare_models()
# Out:
#                                     Model           MAE           MSE  \
# gbr           Gradient Boosting Regressor  1.766546e+04  9.680011e+08
# lightgbm  Light Gradient Boosting Machine  1.798455e+04  9.803394e+08
# rf                Random Forest Regressor  1.910360e+04  1.065324e+09
# et                  Extra Trees Regressor  2.258671e+04  1.430659e+09
# ada                    AdaBoost Regressor  2.628959e+04  1.462561e+09
# ridge                    Ridge Regression  1.998248e+04  1.363115e+09
# lasso                    Lasso Regression  1.964771e+04  1.455279e+09
# omp           Orthogonal Matching Pursuit  1.856201e+04  1.441302e+09
# lr                      Linear Regression  2.372642e+04  1.783824e+09
# en                            Elastic Net  2.170548e+04  1.760583e+09
# dt                Decision Tree Regressor  2.875671e+04  1.989424e+09
# knn                 K Neighbors Regressor  3.141322e+04  2.548500e+09
# ...
